# %%
import cv2
import numpy as np

# Synthetic
#path = '/home/lamberti/work/Dataset/synthetic_chinese_license_plates_LPRNet/crops/000179.png'
# CCPD crops
path = '/home/lamberti/work/Dataset/CCPD_crops/ccpd_base/000009.jpg'

img = cv2.imread(path) 
#cv2.imwrite('/home/lamberti/work/output_debug/temp.png', img)

from matplotlib import pyplot as plt
img = cv2.cvtColor(img.astype(np.uint8), cv2.COLOR_BGR2RGB)
plt.imshow(img, interpolation='nearest')

# %%
from IPython.display import Image
Image(filename='/home/lamberti/work/Dataset/CCPD_crops/ccpd_base/000009.jpg')

# %%
import cv2
path = '/home/lamberti/work/Dataset/CCPD_crops/ccpd_base/000008.jpg'
img = cv2.imread(path) 
cv2.imwrite(  '/home/lamberti/work/my_dataset/ccpd_crops/000008.jpg', img)
# Out:
# True
